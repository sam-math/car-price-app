# %%
import pandas as pd
import requests
import re
import time
import random
import json

# %%
from IPython.display import Image, display

# %%
pd.options.display.max_colwidth = None

# %%
df = pd.read_csv('../06_app/app_files/final_results_df.csv')

# %%
brand_models_df = df[['brand','model']].value_counts(sort=True).reset_index()

# %%
brand_models_df
# Out:
#             brand    model  count
# 0      volkswagen     golf   1051
# 1             bmw  serie 3    708
# 2            seat     leon    666
# 3            seat    ibiza    563
# 4            audi       a3    530
# ...           ...      ...    ...
# 1197        lotus    emira      1
# 1198        lotus    elise      1
# 1199      ferrari      599      1
# 1200      ferrari      612      1
# 1201  rolls-royce  silvier      1
#
# [1202 rows x 3 columns]

# %%
# Function to recursively flatten dictionaries
def flatten_column(df, col):
    df_flat = pd.json_normalize(df[col])
    df_flat.columns = [f"{col}.{subcol}" for subcol in df_flat.columns]  # Prefix nested column names
    return pd.concat([df.drop(columns=[col]), df_flat], axis=1)

# %%
# Function to extract author name
def extract_author(snippet):
    author_pattern = re.search(r'Author\s([\w\s]+)|author name string: ([\w\s]+)', snippet)
    if author_pattern:
        return author_pattern.group(1) or author_pattern.group(2)
    return 'Unknown'

# %%
# Function to check for Creative Commons license
def check_license(snippet):
    if 'Creative Commons Attribution' in snippet or 'CC BY-SA' in snippet:
        return 'CC BY-SA 4.0'
    return 'Unknown License'

# %%
for brand, model in zip(brand_models_df['brand'][:10], brand_models_df['model'][:10]):
    print(brand, model)
# Out:
# volkswagen golf
# bmw serie 3
# seat leon
# seat ibiza
# audi a3
# mercedes-benz clase a
# ford focus
# mercedes-benz clase c
# bmw serie 1
# renault megane

# %%
# Load the config.json file
with open('config.json') as config_file:
    config = json.load(config_file)

all_brand_models = []

# Loop over the brands and models
for brand, model in zip(brand_models_df['brand'], brand_models_df['model']):
  
    # Adjust the brand and model names for URL encoding
    brand_adjusted = brand.replace(' ', '%20')
    model_adjusted = model.replace(' ', '%20')
  
    try:
        # Use the URL template from the config and format it with adjusted brand and model
        url = config['url_template'].format(brand_adjusted=brand_adjusted, model_adjusted=model_adjusted)

        # Define headers and payload from the config
        headers = config['headers']
        payload = config['payload']

        # Send the request
        response = requests.request("GET", url, headers=headers, data=payload)

        # Check if the request was successful
        if response.status_code == 200:
            df = pd.DataFrame(response.json()['query']['pages']).transpose().reset_index(drop=True)

            # Recursively flattening 'details' column
            df_flat = flatten_column(df, 'imageinfo')
            df_flat = flatten_column(df_flat, 'imageinfo.0')  # Flattening nested 'specs'

            df_final = df_flat[['title', 'snippet', 'timestamp', 'index', 'fullurl', 'imageinfo.0.thumburl', 'imageinfo.0.url']].set_index('index').sort_index()

            # Apply the functions to create new columns
            df_final['author'] = df_final['snippet'].apply(extract_author)
            df_final['license'] = df_final['snippet'].apply(check_license)

            # Add brand and model columns
            df_final['brand'] = brand
            df_final['model'] = model

            df_ready = df_final
        else:
            df_ready = pd.DataFrame()

    except Exception as e:
        print(f"There was an error with {brand} {model}. This model is skipped. Error: {e}")
        df_ready = pd.DataFrame()  # Ensure df_ready is defined even in case of error

    # Check if df_ready is not empty
    if not df_ready.empty:
        all_brand_models.append(df_ready)

    # Introduce delay between requests
    delay = random.uniform(2, 3)
    print(f"Request for {brand} {model} completed. Waiting {delay:.2f} seconds before the next request.")
    time.sleep(delay)

print('All requests completed')
# Out:
# Request for nissan nv300 completed. Waiting 2.52 seconds before the next request.
# Request for audi q8 sportback e-tron completed. Waiting 2.98 seconds before the next request.
# Request for citroen ax completed. Waiting 2.47 seconds before the next request.
# Request for peugeot e-traveller completed. Waiting 2.19 seconds before the next request.
# Request for renault mascott completed. Waiting 2.86 seconds before the next request.
# Request for renault vel satis completed. Waiting 2.75 seconds before the next request.
# Request for isuzu trooper completed. Waiting 2.92 seconds before the next request.
# Request for peugeot e-3008 completed. Waiting 2.09 seconds before the next request.
# Request for citroen ami completed. Waiting 2.06 seconds before the next request.
# Request for audi rs7 completed. Waiting 2.36 seconds before the next request.
# Request for lexus gs450h completed. Waiting 2.68 seconds before the next request.
# Request for infiniti qx30 completed. Waiting 2.47 seconds before the next request.
# Request for rover 400 completed. Waiting 2.12 seconds before the next request.
# Request for peugeot 806 completed. Waiting 2.83 seconds before the next request.
# Request for alpine a110 completed. Waiting 2.83 seconds before the next request.
# Request for volvo 940 completed. Waiting 2.58 seconds before the next request.
# Request for mercedes-benz eqs completed. Waiting 2.87 seconds before the next request.
# Request for kia soul ev completed. Waiting 2.31 seconds before the next request.
# Request for tata vista completed. Waiting 2.06 seconds before the next request.
# Request for fiat fullback completed. Waiting 2.47 seconds before the next request.
# Request for aston martin db9 completed. Waiting 2.81 seconds before the next request.
# Request for swm g01f completed. Waiting 2.44 seconds before the next request.
# Request for jeep gladiator completed. Waiting 2.55 seconds before the next request.
# Request for volkswagen id.7 completed. Waiting 2.91 seconds before the next request.
# Request for rover 200 completed. Waiting 2.18 seconds before the next request.
# Request for kia cee'd sportswagon completed. Waiting 2.86 seconds before the next request.
# Request for audi 100 completed. Waiting 2.90 seconds before the next request.
# Request for toyota gt86 completed. Waiting 2.35 seconds before the next request.
# Request for fiat uno completed. Waiting 2.08 seconds before the next request.
# Request for kia e-soul completed. Waiting 2.81 seconds before the next request.
# Request for nissan e-nv200 evalia completed. Waiting 2.76 seconds before the next request.
# Request for renault fluence completed. Waiting 2.40 seconds before the next request.
# Request for nissan np300 pick up completed. Waiting 2.62 seconds before the next request.
# Request for ford maverick completed. Waiting 2.47 seconds before the next request.
# Request for jaguar serie xk completed. Waiting 2.62 seconds before the next request.
# Request for fiat multipla completed. Waiting 2.42 seconds before the next request.
# Request for toyota gr86 completed. Waiting 2.88 seconds before the next request.
# Request for kia pro_cee'd gt completed. Waiting 2.18 seconds before the next request.
# Request for suzuki baleno completed. Waiting 2.14 seconds before the next request.
# Request for nissan gt-r completed. Waiting 2.84 seconds before the next request.
# Request for citroen 2cv completed. Waiting 2.06 seconds before the next request.
# Request for lexus is300 completed. Waiting 2.65 seconds before the next request.
# Request for lexus rx300 completed. Waiting 2.61 seconds before the next request.
# Request for hyundai atos completed. Waiting 2.67 seconds before the next request.
# Request for audi s8 completed. Waiting 2.95 seconds before the next request.
# Request for bmw ix completed. Waiting 2.41 seconds before the next request.
# Request for mitsubishi 3000 gt completed. Waiting 2.52 seconds before the next request.
# Request for mazda rx-8 completed. Waiting 2.94 seconds before the next request.
# There was an error with the skywell be11. This model is skipped. Error: 'pages'
# Request for skywell be11 completed. Waiting 2.20 seconds before the next request.
# Request for honda insight completed. Waiting 2.11 seconds before the next request.
# Request for dodge nitro completed. Waiting 2.99 seconds before the next request.
# Request for mercedes-benz 420 completed. Waiting 2.44 seconds before the next request.
# Request for opel ampera completed. Waiting 2.48 seconds before the next request.
# Request for volkswagen corrado completed. Waiting 2.78 seconds before the next request.
# Request for daihatsu feroza completed. Waiting 2.49 seconds before the next request.
# Request for citroen xm completed. Waiting 2.27 seconds before the next request.
# Request for citroen zx completed. Waiting 2.51 seconds before the next request.
# Request for cadillac srx completed. Waiting 2.74 seconds before the next request.
# Request for daewoo lacetti completed. Waiting 2.76 seconds before the next request.
# There was an error with the mercedes-benz clase sl r129. This model is skipped. Error: 'pages'
# Request for mercedes-benz clase sl r129 completed. Waiting 2.35 seconds before the next request.
# Request for corvette corvette completed. Waiting 2.02 seconds before the next request.
# Request for citroen ë-jumpy completed. Waiting 2.46 seconds before the next request.
# Request for chevrolet epica completed. Waiting 2.44 seconds before the next request.
# Request for renault r9 completed. Waiting 2.70 seconds before the next request.
# Request for dr automobiles dr4 completed. Waiting 2.10 seconds before the next request.
# Request for ds ds 3 crossback e-tense completed. Waiting 2.82 seconds before the next request.
# Request for infiniti m completed. Waiting 2.57 seconds before the next request.
# Request for ssangyong korando kj completed. Waiting 2.04 seconds before the next request.
# Request for subaru crosstrek completed. Waiting 2.48 seconds before the next request.
# Request for fiat 124 spider completed. Waiting 2.37 seconds before the next request.
# Request for lexus rz completed. Waiting 2.66 seconds before the next request.
# Request for mitsubishi space wagon completed. Waiting 2.30 seconds before the next request.
# Request for volkswagen lupo completed. Waiting 2.33 seconds before the next request.
# Request for volvo 240 completed. Waiting 2.10 seconds before the next request.
# Request for mahindra xuv500 completed. Waiting 2.12 seconds before the next request.
# Request for ds ds 9 completed. Waiting 2.28 seconds before the next request.
# Request for maserati granturismo completed. Waiting 2.77 seconds before the next request.
# Request for renault r11 completed. Waiting 2.23 seconds before the next request.
# Request for mazda 323 completed. Waiting 2.24 seconds before the next request.
# Request for mitsubishi carisma completed. Waiting 2.13 seconds before the next request.
# Request for evo cross 4 completed. Waiting 2.53 seconds before the next request.
# Request for alfa romeo gtv completed. Waiting 2.09 seconds before the next request.
# Request for honda e:ny1 completed. Waiting 2.66 seconds before the next request.
# Request for tata indica completed. Waiting 2.75 seconds before the next request.
# Request for toyota dyna completed. Waiting 2.80 seconds before the next request.
# There was an error with the renault twingo e-tech. This model is skipped. Error: 'pages'
# Request for renault twingo e-tech completed. Waiting 2.77 seconds before the next request.
# Request for hyundai h-1 travel completed. Waiting 2.72 seconds before the next request.
# Request for alfa romeo brera completed. Waiting 2.98 seconds before the next request.
# Request for hyundai ioniq 6 completed. Waiting 2.22 seconds before the next request.
# Request for rover mini completed. Waiting 2.56 seconds before the next request.
# Request for toyota corolla sedan completed. Waiting 2.33 seconds before the next request.
# Request for honda s2000 completed. Waiting 2.47 seconds before the next request.
# Request for chrysler stratus completed. Waiting 2.00 seconds before the next request.
# Request for ford cougar completed. Waiting 2.02 seconds before the next request.
# Request for skoda octavia tour completed. Waiting 2.12 seconds before the next request.
# Request for skoda enyaq coupe completed. Waiting 2.28 seconds before the next request.
# Request for ferrari 348 completed. Waiting 2.26 seconds before the next request.
# Request for toyota supra completed. Waiting 2.96 seconds before the next request.
# Request for aston martin vantage v8 completed. Waiting 2.05 seconds before the next request.
# Request for bentley continental gtc completed. Waiting 2.78 seconds before the next request.
# Request for evo evo 3 completed. Waiting 2.90 seconds before the next request.
# Request for opel zafira life completed. Waiting 2.66 seconds before the next request.
# Request for cadillac bls completed. Waiting 2.15 seconds before the next request.
# Request for mercedes-benz clase gls completed. Waiting 2.47 seconds before the next request.
# Request for citroen ë-spacetourer completed. Waiting 2.68 seconds before the next request.
# Request for chevrolet tacuma completed. Waiting 2.92 seconds before the next request.
# Request for opel combo-e life completed. Waiting 2.94 seconds before the next request.
# Request for nissan tiida completed. Waiting 2.15 seconds before the next request.
# Request for opel astra electric completed. Waiting 2.16 seconds before the next request.
# Request for mg zr completed. Waiting 2.69 seconds before the next request.
# Request for ssangyong tivoli grand completed. Waiting 2.31 seconds before the next request.
# Request for seat malaga completed. Waiting 2.08 seconds before the next request.
# Request for nissan vanette cargo completed. Waiting 2.35 seconds before the next request.
# Request for toyota mr2 completed. Waiting 2.15 seconds before the next request.
# Request for ford bronco completed. Waiting 2.15 seconds before the next request.
# Request for kia cee'd sporty wagon completed. Waiting 2.85 seconds before the next request.
# Request for nissan np300 navara completed. Waiting 3.00 seconds before the next request.
# Request for nissan 200 sx completed. Waiting 2.91 seconds before the next request.
# Request for porsche 928 completed. Waiting 2.35 seconds before the next request.
# Request for nissan 100 nx completed. Waiting 2.69 seconds before the next request.
# Request for chevrolet volt completed. Waiting 2.82 seconds before the next request.
# Request for suzuki across completed. Waiting 2.64 seconds before the next request.
# Request for lancia thema completed. Waiting 2.73 seconds before the next request.
# Request for peugeot j5 completed. Waiting 2.03 seconds before the next request.
# Request for subaru solterra completed. Waiting 2.73 seconds before the next request.
# Request for fiat e-ulysse completed. Waiting 2.33 seconds before the next request.
# Request for fiat e-doblò completed. Waiting 2.08 seconds before the next request.
# Request for fiat croma completed. Waiting 2.31 seconds before the next request.
# Request for lexus gs300 completed. Waiting 2.99 seconds before the next request.
# Request for mitsubishi canter completed. Waiting 2.26 seconds before the next request.
# Request for toyota urban cruiser completed. Waiting 2.93 seconds before the next request.
# Request for rover 600 completed. Waiting 2.42 seconds before the next request.
# Request for volkswagen grand california completed. Waiting 2.42 seconds before the next request.
# Request for rover sd completed. Waiting 2.37 seconds before the next request.
# Request for volvo 460 completed. Waiting 2.73 seconds before the next request.
# Request for volvo 480 completed. Waiting 2.00 seconds before the next request.
# Request for suzuki celerio completed. Waiting 2.15 seconds before the next request.
# Request for toyota land cruiser 200 completed. Waiting 2.11 seconds before the next request.
# Request for santana anibal completed. Waiting 2.51 seconds before the next request.
# Request for suzuki splash completed. Waiting 2.12 seconds before the next request.
# Request for rover 25 completed. Waiting 2.36 seconds before the next request.
# Request for abarth 124 spider completed. Waiting 2.62 seconds before the next request.
# Request for dodge durango completed. Waiting 2.05 seconds before the next request.
# Request for hyundai xg completed. Waiting 2.64 seconds before the next request.
# Request for pontiac firebird completed. Waiting 2.99 seconds before the next request.
# Request for mahindra goa pick-up completed. Waiting 2.54 seconds before the next request.
# Request for piaggio porter completed. Waiting 2.58 seconds before the next request.
# There was an error with the dfsk serie k. This model is skipped. Error: 'pages'
# Request for dfsk serie k completed. Waiting 2.12 seconds before the next request.
# Request for infiniti qx70 completed. Waiting 2.16 seconds before the next request.
# Request for honda cr-z completed. Waiting 2.17 seconds before the next request.
# Request for ineos grenadier completed. Waiting 2.45 seconds before the next request.
# Request for byd seal completed. Waiting 2.23 seconds before the next request.
# Request for daewoo tacuma completed. Waiting 2.59 seconds before the next request.
# Request for dr automobiles dr 6 completed. Waiting 2.88 seconds before the next request.
# Request for hyundai veloster completed. Waiting 2.96 seconds before the next request.
# Request for nissan maxima qx completed. Waiting 2.45 seconds before the next request.
# Request for fiat strada completed. Waiting 2.46 seconds before the next request.
# Request for chevrolet tahoe completed. Waiting 2.92 seconds before the next request.
# Request for chrysler le baron completed. Waiting 2.25 seconds before the next request.
# Request for mitsubishi galant completed. Waiting 2.83 seconds before the next request.
# Request for hyundai scoupe completed. Waiting 2.65 seconds before the next request.
# Request for mg zt completed. Waiting 2.00 seconds before the next request.
# Request for pontiac trans am completed. Waiting 2.92 seconds before the next request.
# Request for mercedes-benz mercedes-amg sl completed. Waiting 2.57 seconds before the next request.
# Request for audi 90 completed. Waiting 2.67 seconds before the next request.
# Request for ford scorpio completed. Waiting 2.64 seconds before the next request.
# Request for audi rs5 completed. Waiting 2.95 seconds before the next request.
# Request for evo evo 7 completed. Waiting 2.31 seconds before the next request.
# Request for ferrari 360 completed. Waiting 2.64 seconds before the next request.
# Request for aro 10 completed. Waiting 2.45 seconds before the next request.
# Request for ford pickup completed. Waiting 2.46 seconds before the next request.
# Request for alfa romeo 146 completed. Waiting 2.93 seconds before the next request.
# Request for alfa romeo 166 completed. Waiting 2.82 seconds before the next request.
# Request for evo evo 4 completed. Waiting 2.22 seconds before the next request.
# Request for alfa romeo 75 completed. Waiting 2.87 seconds before the next request.
# Request for fiat brava completed. Waiting 2.33 seconds before the next request.
# Request for aston martin v8 vantage completed. Waiting 2.04 seconds before the next request.
# Request for tata telco completed. Waiting 2.51 seconds before the next request.
# Request for suzuki grand vitara xl-7 completed. Waiting 2.23 seconds before the next request.
# Request for hyundai ix55 completed. Waiting 2.18 seconds before the next request.
# Request for lexus ls400 completed. Waiting 2.97 seconds before the next request.
# Request for citroen cx completed. Waiting 2.50 seconds before the next request.
# Request for kia sephia ii completed. Waiting 2.98 seconds before the next request.
# Request for subaru tribeca completed. Waiting 2.09 seconds before the next request.
# Request for mercedes-benz 140d completed. Waiting 2.57 seconds before the next request.
# Request for citroen visa completed. Waiting 2.76 seconds before the next request.
# Request for daihatsu rocky completed. Waiting 2.59 seconds before the next request.
# Request for toyota paseo completed. Waiting 2.34 seconds before the next request.
# Request for daewoo aranos completed. Waiting 2.81 seconds before the next request.
# Request for daimler serie xj completed. Waiting 2.06 seconds before the next request.
# Request for maxus t90 completed. Waiting 2.42 seconds before the next request.
# Request for lexus ls600h completed. Waiting 2.61 seconds before the next request.
# Request for ssangyong family completed. Waiting 2.13 seconds before the next request.
# Request for ferrari california completed. Waiting 2.95 seconds before the next request.
# Request for maxus euniq 5 completed. Waiting 2.51 seconds before the next request.
# Request for maserati grancabrio completed. Waiting 2.59 seconds before the next request.
# Request for hyundai lantra completed. Waiting 2.86 seconds before the next request.
# Request for ford streetka completed. Waiting 2.58 seconds before the next request.
# Request for subaru b9 tribeca completed. Waiting 2.13 seconds before the next request.
# There was an error with the smart #3. This model is skipped. Error: 'query'
# Request for smart #3 completed. Waiting 2.39 seconds before the next request.
# Request for morgan roadster completed. Waiting 2.27 seconds before the next request.
# Request for mg tf completed. Waiting 2.28 seconds before the next request.
# Request for tata aria completed. Waiting 2.05 seconds before the next request.
# Request for piaggio quargo completed. Waiting 2.78 seconds before the next request.
# Request for porsche 968 completed. Waiting 2.91 seconds before the next request.
# Request for renault alpine completed. Waiting 2.34 seconds before the next request.
# Request for volvo 740 completed. Waiting 2.61 seconds before the next request.
# Request for isuzu d max completed. Waiting 2.71 seconds before the next request.
# Request for audi q8 e-tron completed. Waiting 2.65 seconds before the next request.
# Request for renault r25 completed. Waiting 2.86 seconds before the next request.
# Request for audi tt rs completed. Waiting 2.58 seconds before the next request.
# There was an error with the asia motors rocsta. This model is skipped. Error: 'pages'
# Request for asia motors rocsta completed. Waiting 2.96 seconds before the next request.
# Request for iveco massif completed. Waiting 2.39 seconds before the next request.
# Request for volvo v70 xc completed. Waiting 2.41 seconds before the next request.
# Request for renault scenic e-tech completed. Waiting 2.45 seconds before the next request.
# Request for alfa romeo 33 completed. Waiting 2.13 seconds before the next request.
# Request for abarth 695 completed. Waiting 2.09 seconds before the next request.
# Request for chevrolet trailblazer completed. Waiting 2.28 seconds before the next request.
# Request for lancia y completed. Waiting 2.64 seconds before the next request.
# Request for peugeot ion completed. Waiting 2.63 seconds before the next request.
# Request for opel signum completed. Waiting 2.84 seconds before the next request.
# Request for chevrolet evanda completed. Waiting 2.09 seconds before the next request.
# Request for skoda felicia completed. Waiting 2.61 seconds before the next request.
# Request for cadillac sts completed. Waiting 2.62 seconds before the next request.
# Request for opel corsa electric completed. Waiting 2.93 seconds before the next request.
# Request for kgm rexton completed. Waiting 2.85 seconds before the next request.
# Request for cadillac cts completed. Waiting 2.92 seconds before the next request.
# Request for seat terra completed. Waiting 2.15 seconds before the next request.
# Request for peugeot 3008 plug-in hybrid completed. Waiting 2.53 seconds before the next request.
# Request for austin mini completed. Waiting 2.99 seconds before the next request.
# Request for peugeot 605 completed. Waiting 2.49 seconds before the next request.
# Request for isuzu pick up completed. Waiting 2.16 seconds before the next request.
# Request for honda legend completed. Waiting 2.81 seconds before the next request.
# Request for rover 100 completed. Waiting 2.97 seconds before the next request.
# Request for infiniti qx50 completed. Waiting 2.66 seconds before the next request.
# Request for hyundai genesis completed. Waiting 2.66 seconds before the next request.
# There was an error with the ford grand tourneo custom. This model is skipped. Error: 'pages'
# Request for ford grand tourneo custom completed. Waiting 2.25 seconds before the next request.
# Request for toyota avensis verso completed. Waiting 2.20 seconds before the next request.
# Request for toyota gr supra completed. Waiting 2.42 seconds before the next request.
# Request for tata xenon completed. Waiting 2.79 seconds before the next request.
# Request for fiat punto classic completed. Waiting 2.98 seconds before the next request.
# Request for chevrolet hhr completed. Waiting 2.54 seconds before the next request.
# Request for alfa romeo sprint completed. Waiting 2.29 seconds before the next request.
# Request for aston martin db7 completed. Waiting 2.75 seconds before the next request.
# Request for audi a4 allroad completed. Waiting 2.55 seconds before the next request.
# Request for audi q6 e-tron completed. Waiting 2.94 seconds before the next request.
# Request for audi q8 e-tron sportback completed. Waiting 2.50 seconds before the next request.
# Request for volvo 440 completed. Waiting 2.37 seconds before the next request.
# Request for bentley flying spur completed. Waiting 2.41 seconds before the next request.
# Request for bentley turbo r completed. Waiting 2.11 seconds before the next request.
# Request for bmw xm completed. Waiting 2.20 seconds before the next request.
# Request for cadillac el dorado completed. Waiting 2.03 seconds before the next request.
# Request for volkswagen santana completed. Waiting 2.12 seconds before the next request.
# Request for chrysler neon completed. Waiting 2.79 seconds before the next request.
# Request for fiat panda classic completed. Waiting 2.64 seconds before the next request.
# Request for chrysler vision completed. Waiting 2.75 seconds before the next request.
# Request for citroen e-mehari completed. Waiting 2.99 seconds before the next request.
# Request for daewoo compact completed. Waiting 2.54 seconds before the next request.
# Request for daimler xj completed. Waiting 2.55 seconds before the next request.
# Request for dfsk seres 3 completed. Waiting 2.95 seconds before the next request.
# Request for dodge viper completed. Waiting 2.79 seconds before the next request.
# Request for umm 100 completed. Waiting 2.96 seconds before the next request.
# Request for dr automobiles dr 6.0 completed. Waiting 2.94 seconds before the next request.
# Request for ferrari f430 completed. Waiting 2.59 seconds before the next request.
# Request for toyota previa completed. Waiting 2.39 seconds before the next request.
# Request for fiat doblò cargo completed. Waiting 2.67 seconds before the next request.
# Request for tata telcosport completed. Waiting 2.70 seconds before the next request.
# Request for zhidou d2s completed. Waiting 2.98 seconds before the next request.
# Request for tata safari completed. Waiting 2.80 seconds before the next request.
# There was an error with the kia optima hïbrido enchufable. This model is skipped. Error: 'pages'
# Request for kia optima hïbrido enchufable completed. Waiting 2.90 seconds before the next request.
# Request for renault master propulsion completed. Waiting 2.31 seconds before the next request.
# Request for santana 350 completed. Waiting 2.46 seconds before the next request.
# Request for renault fuego completed. Waiting 2.49 seconds before the next request.
# Request for renault avantime completed. Waiting 2.83 seconds before the next request.
# Request for peugeot partner origin completed. Waiting 2.88 seconds before the next request.
# Request for lexus rx350 completed. Waiting 2.20 seconds before the next request.
# Request for peugeot e-5008 completed. Waiting 2.38 seconds before the next request.
# Request for lexus sc completed. Waiting 2.66 seconds before the next request.
# Request for peugeot 505 completed. Waiting 2.80 seconds before the next request.
# Request for peugeot 309 completed. Waiting 2.57 seconds before the next request.
# Request for maserati 3200 gt completed. Waiting 2.76 seconds before the next request.
# Request for maserati coupe completed. Waiting 2.11 seconds before the next request.
# Request for seres seres 3 completed. Waiting 2.02 seconds before the next request.
# Request for opel ascona completed. Waiting 2.55 seconds before the next request.
# Request for mazda b-2500 completed. Waiting 2.42 seconds before the next request.
# Request for nissan sunny completed. Waiting 2.01 seconds before the next request.
# Request for mazda mpv completed. Waiting 2.36 seconds before the next request.
# Request for morgan 04-apr completed. Waiting 2.26 seconds before the next request.
# Request for mitsubishi space gear completed. Waiting 2.54 seconds before the next request.
# Request for kia optima sw completed. Waiting 2.40 seconds before the next request.
# Request for mercedes-benz 600 completed. Waiting 2.01 seconds before the next request.
# Request for renault spider completed. Waiting 2.76 seconds before the next request.
# Request for renault v.i. camion completed. Waiting 2.45 seconds before the next request.
# Request for kia clarus completed. Waiting 2.94 seconds before the next request.
# Request for suzuki liana completed. Waiting 2.26 seconds before the next request.
# Request for kia niro phev completed. Waiting 2.16 seconds before the next request.
# Request for kgm korando completed. Waiting 2.47 seconds before the next request.
# Request for suzuki kizashi completed. Waiting 2.72 seconds before the next request.
# Request for rover streetwise completed. Waiting 2.02 seconds before the next request.
# Request for suzuki wagon r+ completed. Waiting 2.65 seconds before the next request.
# Request for kgm tivoli completed. Waiting 2.04 seconds before the next request.
# Request for renault r6 completed. Waiting 2.45 seconds before the next request.
# Request for rover 800 completed. Waiting 2.67 seconds before the next request.
# Request for kia k2500 completed. Waiting 2.49 seconds before the next request.
# Request for renault maxity completed. Waiting 2.80 seconds before the next request.
# Request for opel speedster completed. Waiting 2.34 seconds before the next request.
# Request for seat ronda completed. Waiting 2.74 seconds before the next request.
# Request for alfa romeo 4c completed. Waiting 2.86 seconds before the next request.
# Request for volkswagen taro completed. Waiting 2.23 seconds before the next request.
# Request for renault wind completed. Waiting 2.14 seconds before the next request.
# Request for seres seres 5 completed. Waiting 2.90 seconds before the next request.
# Request for opel zafira-e life completed. Waiting 2.96 seconds before the next request.
# Request for cadillac xlr completed. Waiting 2.77 seconds before the next request.
# Request for chevrolet corvette stingray completed. Waiting 2.06 seconds before the next request.
# Request for nissan cube completed. Waiting 2.41 seconds before the next request.
# Request for abarth punto evo completed. Waiting 2.15 seconds before the next request.
# Request for morgan 4 completed. Waiting 2.34 seconds before the next request.
# Request for chevrolet malibu completed. Waiting 2.14 seconds before the next request.
# Request for rolls-royce silver seraph completed. Waiting 2.07 seconds before the next request.
# Request for mitsubishi i-miev completed. Waiting 2.54 seconds before the next request.
# There was an error with the bertone freeclimber diesel. This model is skipped. Error: 'pages'
# Request for bertone freeclimber diesel completed. Waiting 2.98 seconds before the next request.
# There was an error with the auverland diesel. This model is skipped. Error: 'pages'
# Request for auverland diesel completed. Waiting 2.55 seconds before the next request.
# Request for bentley mulsanne completed. Waiting 2.91 seconds before the next request.
# Request for volvo 960 completed. Waiting 2.05 seconds before the next request.
# Request for aston martin vanquish completed. Waiting 2.73 seconds before the next request.
# Request for aston martin vantage completed. Waiting 2.30 seconds before the next request.
# Request for audi 200 completed. Waiting 2.68 seconds before the next request.
# Request for volvo s60 cross country completed. Waiting 2.03 seconds before the next request.
# Request for saab 9000 completed. Waiting 2.16 seconds before the next request.
# There was an error with the renault kangoo combi e-tech. This model is skipped. Error: 'pages'
# Request for renault kangoo combi e-tech completed. Waiting 2.42 seconds before the next request.
# Request for aro expander completed. Waiting 2.03 seconds before the next request.
# Request for audi rs2 completed. Waiting 2.73 seconds before the next request.
# Request for skoda s completed. Waiting 2.51 seconds before the next request.
# Request for bentley bentayga completed. Waiting 2.12 seconds before the next request.
# Request for audi s2 completed. Waiting 2.22 seconds before the next request.
# Request for renault rafale completed. Waiting 2.17 seconds before the next request.
# Request for audi v8 completed. Waiting 2.51 seconds before the next request.
# Request for rover cabriolet completed. Waiting 2.34 seconds before the next request.
# Request for volvo 360 completed. Waiting 2.81 seconds before the next request.
# Request for volvo 340 completed. Waiting 2.43 seconds before the next request.
# Request for renault safrane completed. Waiting 2.49 seconds before the next request.
# Request for austin mini moke completed. Waiting 2.58 seconds before the next request.
# There was an error with the santana anibal pick up. This model is skipped. Error: 'pages'
# Request for santana anibal pick up completed. Waiting 2.39 seconds before the next request.
# Request for smart crossblade completed. Waiting 2.58 seconds before the next request.
# Request for chrysler saratoga completed. Waiting 2.52 seconds before the next request.
# Request for galloper santamo completed. Waiting 2.34 seconds before the next request.
# Request for fiat argenta completed. Waiting 2.16 seconds before the next request.
# Request for lexus lc completed. Waiting 2.51 seconds before the next request.
# Request for ldv maxus completed. Waiting 2.35 seconds before the next request.
# Request for fiat palio weekend completed. Waiting 2.52 seconds before the next request.
# Request for lancia ypsilon elefantino completed. Waiting 2.65 seconds before the next request.
# Request for lancia dedra completed. Waiting 2.02 seconds before the next request.
# Request for lamborghini gallardo completed. Waiting 2.51 seconds before the next request.
# Request for ford connect completed. Waiting 2.89 seconds before the next request.
# Request for ford granada completed. Waiting 2.30 seconds before the next request.
# Request for lada 214 completed. Waiting 2.61 seconds before the next request.
# Request for kia pride completed. Waiting 2.47 seconds before the next request.
# Request for kia optima phev completed. Waiting 2.33 seconds before the next request.
# Request for kia optima gt completed. Waiting 2.08 seconds before the next request.
# Request for mazda rx7 completed. Waiting 2.74 seconds before the next request.
# Request for hyundai grandeur completed. Waiting 2.51 seconds before the next request.
# Request for hyundai i800 completed. Waiting 2.80 seconds before the next request.
# Request for kia magentis completed. Waiting 2.40 seconds before the next request.
# Request for kia k2500 frontier completed. Waiting 2.29 seconds before the next request.
# Request for hyundai sonata fl completed. Waiting 2.06 seconds before the next request.
# Request for kia joice completed. Waiting 2.00 seconds before the next request.
# Request for kgm torres completed. Waiting 2.84 seconds before the next request.
# Request for talbot horizon completed. Waiting 2.11 seconds before the next request.
# Request for talbot samba completed. Waiting 2.72 seconds before the next request.
# Request for isuzu rodeo completed. Waiting 2.46 seconds before the next request.
# Request for kgm musso completed. Waiting 2.56 seconds before the next request.
# Request for tata tl pick up completed. Waiting 2.22 seconds before the next request.
# Request for subaru justy completed. Waiting 2.54 seconds before the next request.
# Request for lexus ls430 completed. Waiting 2.80 seconds before the next request.
# Request for ferrari mondial completed. Waiting 2.40 seconds before the next request.
# Request for lexus ls460 completed. Waiting 2.17 seconds before the next request.
# Request for mazda mx6 completed. Waiting 2.31 seconds before the next request.
# Request for mazda mx3 completed. Waiting 2.96 seconds before the next request.
# Request for citroen ë-c3 completed. Waiting 2.59 seconds before the next request.
# Request for citroen ë-c3 aircross completed. Waiting 2.15 seconds before the next request.
# Request for tata indigo completed. Waiting 2.35 seconds before the next request.
# Request for daewoo leganza completed. Waiting 2.16 seconds before the next request.
# Request for mazda cx-80 completed. Waiting 2.39 seconds before the next request.
# Request for daihatsu applause completed. Waiting 2.64 seconds before the next request.
# Request for daihatsu sirion completed. Waiting 2.90 seconds before the next request.
# Request for mazda 929 completed. Waiting 2.49 seconds before the next request.
# Request for daimler series iii completed. Waiting 2.35 seconds before the next request.
# Request for mazda 121 completed. Waiting 2.14 seconds before the next request.
# Request for ssangyong actyon sports pick up completed. Waiting 2.50 seconds before the next request.
# There was an error with the ssangyong k4d. This model is skipped. Error: 'pages'
# Request for ssangyong k4d completed. Waiting 2.88 seconds before the next request.
# Request for dr automobiles dr 3 completed. Waiting 2.98 seconds before the next request.
# Request for vaz 215 completed. Waiting 2.90 seconds before the next request.
# Request for mahindra pikup completed. Waiting 2.93 seconds before the next request.
# Request for toyota yaris verso completed. Waiting 2.37 seconds before the next request.
# Request for dr automobiles dr 3.0 completed. Waiting 2.91 seconds before the next request.
# Request for mahindra goa completed. Waiting 2.17 seconds before the next request.
# Request for lotus exige completed. Waiting 2.66 seconds before the next request.
# Request for lotus emira completed. Waiting 2.91 seconds before the next request.
# Request for lotus elise completed. Waiting 2.77 seconds before the next request.
# Request for ferrari 599 completed. Waiting 2.86 seconds before the next request.
# Request for ferrari 612 completed. Waiting 2.93 seconds before the next request.
# There was an error with the rolls-royce silvier. This model is skipped. Error: 'pages'
# Request for rolls-royce silvier completed. Waiting 2.55 seconds before the next request.
# All requests completed

# %%
df = pd.concat(all_brand_models)

# %%
df.to_csv('../06_app/app_files/car_pictures_table_all.csv', index=False)

# %%
df = pd.read_csv('../06_app/app_files/car_pictures_table_all.csv')

# %%
# df_all.to_csv('car_pictures_table_all.csv', index=False)

# %%
# df_all['author'].value_counts().head(50)
# Out:
# author
# Unknown                                      21638
# Dinkun Chen Wikimedia username                3219
# Alexander                                     1793
# Rudolf Stricker Permission                     823
# Alexander Migl                                 687
# Calreyn88                                      526
# Thomas doerfer Other versions                  429
# Dinkun                                         400
# Tokumeigakarinoaoshima                         368
# Benespit Wikimedia username                    277
# Dinkun Chen Wikimedia                          273
# Dinkun Chen                                    254
# Chu Other versions                             253
# M 93 Other versions                            246
# order_242                                      210
# Thomas doerfer                                 196
# Tennen                                         192
# Charles01                                      189
# Calreyn88 Wikimedia username                   176
# MercurySable99 Wikimedia username              155
# order_242 from Chile                           143
# RL GNZLZ from Chile                            143
# Rudolf Stricker Permission                     141
# Corvettec6r                                    134
# Handelsgeselschaft Wikimedia username          121
# Vauxford                                       120
# Navigator84                                    115
# DestinationFearFan                             108
# Damian B Oh                                    104
# Ben                                            104
# M                                              104
# M 93                                           101
# Herranderssvensson                              87
# Dogs                                            86
# MrWalkr Wikimedia username                      82
# JustAnotherCarDesigner Wikimedia username       82
# CEFICEFI                                        81
# Mariordo                                        81
# Jakub                                           77
# Zotyefan Wikimedia username                     77
# Benespit Wikimedia                              77
# Bene Riobó                                      74
# Overlaet                                        72
# Dorieo                                          70
# Damian B Oh Wikimedia username                  68
# Jengtingchen                                    66
# RL GNZLZ                                        62
# Raf24                                           58
# order_242 from                                  55
# Mr                                              54
# Name: count, dtype: int64

# %%
# selected_picture = df[df['author'] != 'Unknown'].reset_index(drop=True).iloc[[0],:]

# %%
# selected_picture
# Out:
#                                       title  \
# 0  File:Volkswagen Golf VIII R 1X7A7089.jpg
#
#                                                                                                                                                                                                                                                                                   snippet  \
# 0  Description<span class="searchmatch">Volkswagen</span> <span class="searchmatch">Golf</span> VIII R 1X7A7089.jpg <span class="searchmatch">Volkswagen</span> <span class="searchmatch">Golf</span> VIII R in Stuttgart-Vaihingen Date 7 April 2023 Source Own work Author Alexander-93
#
#               timestamp  \
# 0  2023-04-07T14:58:56Z
#
#                                                                        fullurl  \
# 0  https://commons.wikimedia.org/wiki/File:Volkswagen_Golf_VIII_R_1X7A7089.jpg
#
#                                                                                                                       imageinfo.0.thumburl  \
# 0  https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Volkswagen_Golf_VIII_R_1X7A7089.jpg/332px-Volkswagen_Golf_VIII_R_1X7A7089.jpg
#
#                                                                            imageinfo.0.url  \
# 0  https://upload.wikimedia.org/wikipedia/commons/4/4f/Volkswagen_Golf_VIII_R_1X7A7089.jpg
#
#       author          license       brand model
# 0  Alexander  Unknown License  volkswagen  golf

# %%
# selected_picture['imageinfo.0.thumburl'][0]
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Volkswagen_Golf_VIII_R_1X7A7089.jpg/332px-Volkswagen_Golf_VIII_R_1X7A7089.jpg'

# %%
# image_url = selected_picture['imageinfo.0.thumburl'][0]

# %%
# display(Image(url=image_url))
# Out:
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/4f/Volkswagen_Golf_VIII_R_1X7A7089.jpg/332px-Volkswagen_Golf_VIII_R_1X7A7089.jpg"/>

# %%
# df_all = pd.read_parquet('../04_EDA/coches_net_model.parquet')

# %%
# df_all[['brand','model', 'year']].value_counts().reset_index().head(50)
# Out:
#             brand      model  year  count
# 0   mercedes-benz    clase a  2023    456
# 1      volkswagen       golf  2019    455
# 2      volkswagen       golf  2021    376
# 3      volkswagen       golf  2020    360
# 4   mercedes-benz    clase a  2020    352
# 5   mercedes-benz    clase a  2019    344
# 6            fiat        500  2022    342
# 7         peugeot       3008  2019    332
# 8         hyundai     tucson  2022    327
# 9            seat       leon  2019    323
# 10     volkswagen       golf  2018    322
# 11        renault       clio  2019    320
# 12         toyota    corolla  2020    305
# 13           fiat        500  2021    299
# 14           seat       leon  2020    287
# 15            bmw    serie 3  2007    283
# 16         toyota       c-hr  2020    276
# 17         nissan    qashqai  2023    274
# 18     volkswagen       golf  2017    273
# 19        peugeot       3008  2022    269
# 20            bmw    serie 1  2021    268
# 21           seat       leon  2018    267
# 22      lynk & co         01  2022    266
# 23            bmw         x1  2019    265
# 24     volkswagen       golf  2015    265
# 25        peugeot       2008  2020    260
# 26           seat       leon  2021    259
# 27            kia   sportage  2023    258
# 28     volkswagen       golf  2010    256
# 29        citroen   berlingo  2019    255
# 30     volkswagen       golf  2014    253
# 31        hyundai     tucson  2023    251
# 32     volkswagen       golf  2016    249
# 33     volkswagen      t-roc  2020    247
# 34        peugeot       2008  2021    246
# 35           fiat        500  2020    241
# 36        peugeot       2008  2023    240
# 37          cupra  formentor  2022    236
# 38        peugeot        308  2019    232
# 39        peugeot       3008  2018    232
# 40        peugeot        208  2023    232
# 41        peugeot       3008  2020    231
# 42            bmw    serie 3  2020    227
# 43  mercedes-benz    clase c  2019    227
# 44     volkswagen     tiguan  2019    226
# 45           audi         a1  2020    222
# 46           ford      focus  2019    222
# 47            bmw    serie 3  2008    219
# 48            kia       ceed  2023    219
# 49        peugeot     rifter  2019    218
